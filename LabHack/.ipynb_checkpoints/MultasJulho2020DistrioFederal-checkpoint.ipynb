# %%
import pandas as pd
# %matplotlib inline
df=pd.read_csv("MultasJulho2020DistritoFederal.csv", sep=";")

df.head()
# Out:
#   tipo_infracao                                          descricao  \
# 0        7455-0  Transitar em velocidade superior à máxima perm...
# 1        7463-0  Transitar em velocidade superior à máxima perm...
# 2        7463-0  Transitar em velocidade superior à máxima perm...
# 3        7455-0  Transitar em velocidade superior à máxima perm...
# 4        7455-0  Transitar em velocidade superior à máxima perm...
#
#   tipo_infrator               tipo_veiculo cometimento hora_cometimento  \
# 0      Condutor  MOTOCICLET                 01/07/2020            00:02
# 1      Condutor  UTILITARIO                 01/07/2020            00:04
# 2      Condutor  CAMINHAO                   01/07/2020            00:05
# 3      Condutor  AUTOMOVEL                  01/07/2020            00:06
# 4      Condutor  UTILITARIO                 01/07/2020            00:07
#
#                                  auinf_local_rodovia auinf_local_km  \
# ...

# %%
df['tipo_infrator'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['hora_cometimento'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %%
df.tail()
# Out:
#       tipo_infracao                                          descricao  \
# 77343        7455-0  Transitar em velocidade superior à máxima perm...
# 77344        7455-0  Transitar em velocidade superior à máxima perm...
# 77345        7455-0  Transitar em velocidade superior à máxima perm...
# 77346        7455-0  Transitar em velocidade superior à máxima perm...
# 77347        7455-0  Transitar em velocidade superior à máxima perm...
#
#       tipo_infrator               tipo_veiculo cometimento hora_cometimento  \
# 77343      Condutor  CAMINHAO                   31/07/2020            23:57
# 77344      Condutor  AUTOMOVEL                  31/07/2020            23:57
# 77345      Condutor  AUTOMOVEL                  31/07/2020            23:57
# 77346      Condutor  MOTOCICLET                 31/07/2020            23:57
# 77347      Condutor  CAMINHAO                   31/07/2020            23:59
#
#                                      auinf_local_rodovia auinf_local_km  \
# ...
