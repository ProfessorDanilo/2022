# %%
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('genero-nomes-2020.csv')
df.head()
# Out:
#                                    alternative_names classification  \
# 0  AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...              F
# 1                                         ARAAO|ARAO              M
# 2                       AHARON|AROM|ARON|ARYON|HARON              M
# 3                            ADA|ADAH|ADAR|ADHA|HADA              F
# 4                                                NaN              M
#
#   first_name  frequency_female  frequency_male  frequency_total  \
# 0     AALINE              66.0             NaN               66
# 1      AARAO               NaN           281.0              281
# 2      AARON               NaN           676.0              676
# 3        ABA              82.0             NaN               82
# 4      ABADE               NaN            57.0               57
#
#    frequency_group group_name  ratio
# 0           530550      ALINE    1.0
# 1             3526       ARAO    1.0
# 2             3442       ARON    1.0
# ...

# %%
df.count()
# Out:
# alternative_names     70745
# classification       100787
# first_name           100787
# frequency_female      60484
# frequency_male        50932
# frequency_total      100787
# frequency_group      100787
# group_name           100787
# ratio                100787
# dtype: int64

# %%
df.sample(10)
# Out:
#                                        alternative_names classification  \
# 27477  AALINE|AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINH...              F
# 64728                                                NaN              F
# 16337                           BASIL|DASIEL|DASIL|DAZIL              M
# 65918                                            OZIMARA              F
# 19185                                                NaN              M
# 98548                              GLEIDISSON|GLEYDISSON              M
# 69603                                                NaN              M
# 17217                                   DENANCIR|DENANCY              F
# 32470                                                NaN              F
# 5044                                                 NaN              F
#
#        first_name  frequency_female  frequency_male  frequency_total  \
# 27477      EULINE             156.0             NaN              156
# ...

# %%
df[df['first_name']== 'DANILO']
# Out:
#                                        alternative_names classification  \
# 15687  DANIELO|DANIILO|DANLO|DANNILO|DANNYLO|DANOLO|D...              M
#
#       first_name  frequency_female  frequency_male  frequency_total  \
# 15687     DANILO            1474.0        231855.0           233329
#
#        frequency_group group_name     ratio
# 15687           234409     DANILO  0.993683

# %%
df[df['first_name']== 'JOSE']
# Out:
#                        alternative_names classification first_name  \
# 45450  GOSE|JHOSE|JOSEH|JOSER|JOZE|JOZER              M       JOSE
#
#        frequency_female  frequency_male  frequency_total  frequency_group  \
# 45450           22021.0       5732508.0          5754529          5766013
#
#       group_name     ratio
# 45450       JOSE  0.996173
